# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Import necessary ibrary

# %%
# import necessary library

import numpy as np
import pandas as pd

# %% [markdown]
# ### Connect colab to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read dataset into Pandas Dataframe

df_mount = pd.read_csv('/content/drive/My Drive/dataset/datagunung_lvl.csv',delimiter=',')
df_mount = df_gunung.rename(columns={"Id": "mountain_id"})
df_mount.head()
# Out:
#    mountain_id     Daerah             Nama_Gunung  Ketinggian   \
# 0          101  Jawa barat          Gunung Cermai        3,078
# 1          102  Jawa barat          Gunung Puntang       2,223
# 2          103  Jawa barat      Gunung Papandayan        2,666
# 3          104  Jawa barat  Gunung Gede Pangrango        2,958
# 4          105  Jawa barat        Gunung Pangrango       3,019
#
#                                Lokasi            Trek  \
# 0  Kuningan, Majalengka, dan Cirebon.    Tanah Kering
# 1                         Kab. Bandung   Tanah kering
# 2                          Kab. Garut.      bebatuan
# 3                                Bogor  Tangga Buatan
# 4                              Cibodas   Akar Pohon
#
#                                           Jalur  Simaksi   Level
# 0  Jalur Apuy, Linggarjati dan Jalur Palutungan  Rp30.000      1
# 1                                             -  Rp40.000      1
# 2                                             -  Rp60.000      1
# 3                Jalur Cibodas dan Jalur Putri   Rp75.000      1
# 4                                 Jalur Cibodas  Rp75.000      2

# %%
# check how many data in df_mount dataframe
df_mount.shape
# Out:
# (17, 9)

# %%
# Load Information from df_mount dataframe
df_mount.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mountain_id   17 non-null     int64
#  1   Daerah        17 non-null     object
#  2   Nama_Gunung   17 non-null     object
#  3   Ketinggian    17 non-null     object
#  4   Lokasi        17 non-null     object
#  5   Trek          17 non-null     object
#  6   Jalur         17 non-null     object
#  7   Simaksi       17 non-null     object
#  8   Level         17 non-null     int64
# dtypes: int64(2), object(7)
# memory usage: 1.3+ KB

# %%
# Read dataset into Pandas Dataframe

df_user = pd.read_csv('/content/drive/My Drive/dataset/MOCK_DATA.csv',delimiter=',')
df_user.head()
# Out:
#    Id                 Nama                         Email      Password  \
# 0   1  Harcourt Leppington    hleppington0@reference.com        Zjvy1t
# 1   2         Cristi Weeds     cweeds1@blogtalkradio.com     GRjASvqhv
# 2   3        Thorny Gidden  tgidden2@acquirethisname.com  hTBgDny2C2p7
# 3   4     Thibaut Spurdens       tspurdens3@omniture.com     aUz4mmfRq
# 4   5      Cristionna Gaul            cgaul4@storify.com       5dU6hdn
#
#      Domisili Jenis Kelamin  Umur  Pengalaman
# 0  Yogyakarta     Perempuan    24          12
# 1     Cilacap     Laki-laki    18           5
# 2    Semarang     Perempuan    48           9
# 3     Cilacap     Perempuan    54          10
# 4      Malang     Laki-laki    61          18

# %%
# check how many data in df_user dataframe
df_user.shape
# Out:
# (1000, 8)

# %%
# Load Information from df_user dataframe
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1000 non-null   int64
#  1   Nama           1000 non-null   object
#  2   Email          1000 non-null   object
#  3   Password       1000 non-null   object
#  4   Domisili       1000 non-null   object
#  5   Jenis Kelamin  1000 non-null   object
#  6   Umur           1000 non-null   int64
#  7   Pengalaman     1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Read dataset into Pandas Dataframe

df_rating = pd.read_csv('/content/drive/My Drive/dataset/rating_data.csv',delimiter=',')
df_rating.head()
# Out:
#    user_id  mountain_id  rating
# 0      284           13       2
# 1       33           11       5
# 2      167            8       1
# 3      623            5       5
# 4      378           10       1

# %%
# check how many data in df_rating dataframe
df_rating.shape
# Out:
# (5000, 3)

# %%
# Load Information from df_rating dataframe
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5000 non-null   int64
#  1   mountain_id  5000 non-null   int64
#  2   rating       5000 non-null   int64
# dtypes: int64(3)
# memory usage: 117.3 KB

# %%
# modify mountain_id in df_rating dataframe
df_rating['mountain_id'] = df_rating['mountain_id']+100

# %%
# add level of users
def level_stats(value):
    if value <= 5:
        return 1
    if 5 < value <= 10:
        return 2
    elif value> 10:
        return 3

df_user['level'] = df_user['Pengalaman'].map(level_stats)
df_user.head()
# Out:
#    Id                 Nama                         Email      Password  \
# 0   1  Harcourt Leppington    hleppington0@reference.com        Zjvy1t
# 1   2         Cristi Weeds     cweeds1@blogtalkradio.com     GRjASvqhv
# 2   3        Thorny Gidden  tgidden2@acquirethisname.com  hTBgDny2C2p7
# 3   4     Thibaut Spurdens       tspurdens3@omniture.com     aUz4mmfRq
# 4   5      Cristionna Gaul            cgaul4@storify.com       5dU6hdn
#
#      Domisili Jenis Kelamin  Umur  Pengalaman  level
# 0  Yogyakarta     Perempuan    24          12      3
# 1     Cilacap     Laki-laki    18           5      1
# 2    Semarang     Perempuan    48           9      2
# 3     Cilacap     Perempuan    54          10      2
# 4      Malang     Laki-laki    61          18      3

# %%
# sort data base on user_id
df_rating = df_rating.sort_values(['user_id']).reset_index(drop=True)
df_rating.head()
# Out:
#    user_id  mountain_id  rating
# 0        1          117       4
# 1        1          109       1
# 2        1          112       2
# 3        1          113       1
# 4        2          104       5

# %%
# Add list mount_name to df_rating dataset

mountain_id = df_rating['mountain_id']
# List of conditions
conditions = [
    (mountain_id == 101),
    (mountain_id == 102),
    (mountain_id == 103),
    (mountain_id == 104),
    (mountain_id == 105),
    (mountain_id == 106),
    (mountain_id == 107),
    (mountain_id == 108),
    (mountain_id == 109),
    (mountain_id == 110),
    (mountain_id == 111),
    (mountain_id == 112),
    (mountain_id == 113),
    (mountain_id == 114),
    (mountain_id == 115),
    (mountain_id == 116),
    (mountain_id == 117)]
# List of values to return
choices  = [
    "Gunung Cermai",
    "Gunung Puntang",
    "Gunung Papandayan",
    "Gunung Gede",
    "Gunung Pangrango",
    "Gunung Cikuray",
    "Gunung Prau",
    "Gunung Merbabu",
    "Gunung Sindoro",
    "Gunung Slamet",
    "Gunung Sumbing",
    "Gunung Arjuno",
    "Gunung Argopuro",
    "Gunung Lawu",
    "Gunung Semeru",
    "Gunung Raung",
    "Gunung Panderman",

]
# create a new column in the DF based on the conditions
df_rating.insert(2, 'mount_name', np.select(conditions, choices, "ERROR"))

# %%
# add level of users

user_id = df_rating['user_id']
level = df_user['level']

#print(level.loc[0])
def level_stats(value):
  for a in user_id:
    if value == a:
      data = df_user.loc[df_user['Id'] == value].reset_index()
      data = data['level']
      return (data.iloc[0])


df_rating['level'] = df_rating['user_id'].map(level_stats)
df_rating.head(10)
# Out:
#    user_id  mountain_id         mount_name  rating  level
# 0        1          117   Gunung Panderman       4      3
# 1        1          109     Gunung Sindoro       1      3
# 2        1          112      Gunung Arjuno       2      3
# 3        1          113    Gunung Argopuro       1      3
# 4        2          104        Gunung Gede       5      1
# 5        2          103  Gunung Papandayan       2      1
# 6        2          112      Gunung Arjuno       1      1
# 7        2          109     Gunung Sindoro       4      1
# 8        2          108     Gunung Merbabu       5      1
# 9        2          112      Gunung Arjuno       4      1

# %%
# add gender column to df_rating dataframe

user_id = df_rating['user_id']
level = df_user['level']

#print(level.loc[0])
def level_stats(value):
  for a in user_id:
    if value == a:
      data = df_user.loc[df_user['Id'] == value].reset_index()
      data = data['Jenis Kelamin']
      return (data.iloc[0])


df_rating['gender'] = df_rating['user_id'].map(level_stats)
df_rating.head(15)
# Out:
#     user_id  mountain_id         mount_name  rating  level     gender
# 0         1          117   Gunung Panderman       4      3  Perempuan
# 1         1          109     Gunung Sindoro       1      3  Perempuan
# 2         1          112      Gunung Arjuno       2      3  Perempuan
# 3         1          113    Gunung Argopuro       1      3  Perempuan
# 4         2          104        Gunung Gede       5      1  Laki-laki
# 5         2          103  Gunung Papandayan       2      1  Laki-laki
# 6         2          112      Gunung Arjuno       1      1  Laki-laki
# 7         2          109     Gunung Sindoro       4      1  Laki-laki
# 8         2          108     Gunung Merbabu       5      1  Laki-laki
# 9         2          112      Gunung Arjuno       4      1  Laki-laki
# 10        3          107        Gunung Prau       2      2  Perempuan
# 11        3          105   Gunung Pangrango       2      2  Perempuan
# 12        3          114        Gunung Lawu       4      2  Perempuan
# 13        3          105   Gunung Pangrango       5      2  Perempuan
# 14        3          104        Gunung Gede       2      2  Perempuan

# %%
# add user's age
user_id = df_rating['user_id']
level = df_user['level']

#print(level.loc[0])
def level_stats(value):
  for a in user_id:
    if value == a:
      data = df_user.loc[df_user['Id'] == value].reset_index()
      data = data['Umur']
      return (data.iloc[0])


df_rating['age'] = df_rating['user_id'].map(level_stats)
df_rating.head(15)
# Out:
#     user_id  mountain_id         mount_name  rating  level     gender  age
# 0         1          117   Gunung Panderman       4      3  Perempuan   24
# 1         1          109     Gunung Sindoro       1      3  Perempuan   24
# 2         1          112      Gunung Arjuno       2      3  Perempuan   24
# 3         1          113    Gunung Argopuro       1      3  Perempuan   24
# 4         2          104        Gunung Gede       5      1  Laki-laki   18
# 5         2          103  Gunung Papandayan       2      1  Laki-laki   18
# 6         2          112      Gunung Arjuno       1      1  Laki-laki   18
# 7         2          109     Gunung Sindoro       4      1  Laki-laki   18
# 8         2          108     Gunung Merbabu       5      1  Laki-laki   18
# 9         2          112      Gunung Arjuno       4      1  Laki-laki   18
# 10        3          107        Gunung Prau       2      2  Perempuan   48
# 11        3          105   Gunung Pangrango       2      2  Perempuan   48
# 12        3          114        Gunung Lawu       4      2  Perempuan   48
# 13        3          105   Gunung Pangrango       5      2  Perempuan   48
# 14        3          104        Gunung Gede       2      2  Perempuan   48

# %%
# Get to know shape and information from df_rating dataframe

print(df_rating.shape)
print(df_rating.info())
# Out:
# (5000, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      5000 non-null   int64
#  1   mountain_id  5000 non-null   int64
#  2   mount_name   5000 non-null   object
#  3   rating       5000 non-null   int64
#  4   level        5000 non-null   int64
#  5   gender       5000 non-null   object
#  6   age          5000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 273.6+ KB
# None

# %%
# sort df_rating base on mountain_id column
df_rating = df_rating.sort_values(['mountain_id']).reset_index(drop=True)
df_rating.head(15)
# Out:
#     user_id  mountain_id     mount_name  rating  level     gender  age
# 0       571          101  Gunung Cermai       2      3  Laki-laki   61
# 1       463          101  Gunung Cermai       4      2  Perempuan   21
# 2       972          101  Gunung Cermai       3      1  Laki-laki   59
# 3       776          101  Gunung Cermai       5      3  Laki-laki   51
# 4       863          101  Gunung Cermai       2      3  Laki-laki   49
# 5       609          101  Gunung Cermai       4      1  Laki-laki   68
# 6       972          101  Gunung Cermai       1      1  Laki-laki   59
# 7       610          101  Gunung Cermai       5      2  Laki-laki   59
# 8       610          101  Gunung Cermai       3      2  Laki-laki   59
# 9       366          101  Gunung Cermai       5      2  Laki-laki   58
# 10      215          101  Gunung Cermai       2      3  Perempuan   24
# 11      365          101  Gunung Cermai       4      1  Perempuan   54
# 12      265          101  Gunung Cermai       5      3  Perempuan   18
# 13      606          101  Gunung Cermai       4      3  Laki-laki   28
# 14      864          101  Gunung Cermai       2      1  Perempuan   56

# %%
# drop level and age columns

data_rating = df_rating.drop(['level','age'],axis=1)
data_rating.head()
# Out:
#    user_id  mountain_id     mount_name  rating     gender
# 0      571          101  Gunung Cermai       2  Laki-laki
# 1      463          101  Gunung Cermai       4  Perempuan
# 2      972          101  Gunung Cermai       3  Laki-laki
# 3      776          101  Gunung Cermai       5  Laki-laki
# 4      863          101  Gunung Cermai       2  Laki-laki

# %%
# Check the average rating of each mountain

avg_mount_rate = data_rating.groupby(['mountain_id']).mean()
avg_mount_rate = avg_mount_rate.drop(['user_id'],axis=1)
avg_mount_rate = avg_mount_rate.sort_values(['rating'], ascending=False)
avg_mount_rate.head()
# Out:
# <ipython-input-40-8090b665774f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_mount_rate = data_rating.groupby(['mountain_id']).mean()
#                rating
# mountain_id
# 117          3.190000
# 114          3.151724
# 103          3.104418
# 107          3.048544
# 101          3.045752

# %%
# check how many each user rated mount

count_user = df_rating.groupby(['user_id']).count()
count_user = count_user.drop(['mountain_id'],axis=1)
count_user = count_user.sort_values(['user_id'], ascending=True)
count_user.head()
# Out:
#          mount_name  rating  level  gender  age
# user_id
# 1                 4       4      4       4    4
# 2                 6       6      6       6    6
# 3                 7       7      7       7    7
# 4                 4       4      4       4    4
# 5                 4       4      4       4    4

# %%
# import tensorflow

import tensorflow as tf

# %%
## Convert Pandas Daframe to Tensorflow dataset

tf_rating = tf.data.Dataset.from_tensor_slices(dict(df_rating))
tf_mount = tf.data.Dataset.from_tensor_slices(dict(df_mount))

# %%
# get the first rows of the mount dataset
for m in tf_mount.take(5):
  print(m)
# Out:
# {'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'Daerah ': <tf.Tensor: shape=(), dtype=string, numpy=b'Jawa barat'>, 'Nama_Gunung ': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai '>, 'Ketinggian ': <tf.Tensor: shape=(), dtype=string, numpy=b'3,078'>, 'Lokasi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Kuningan, Majalengka, dan Cirebon. '>, 'Trek': <tf.Tensor: shape=(), dtype=string, numpy=b'Tanah Kering'>, 'Jalur': <tf.Tensor: shape=(), dtype=string, numpy=b'Jalur Apuy, Linggarjati dan Jalur Palutungan'>, 'Simaksi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Rp30.000'>, 'Level': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# {'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=102>, 'Daerah ': <tf.Tensor: shape=(), dtype=string, numpy=b'Jawa barat'>, 'Nama_Gunung ': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Puntang'>, 'Ketinggian ': <tf.Tensor: shape=(), dtype=string, numpy=b'2,223'>, 'Lokasi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Kab. Bandung'>, 'Trek': <tf.Tensor: shape=(), dtype=string, numpy=b'Tanah kering'>, 'Jalur': <tf.Tensor: shape=(), dtype=string, numpy=b'-'>, 'Simaksi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Rp40.000'>, 'Level': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# {'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=103>, 'Daerah ': <tf.Tensor: shape=(), dtype=string, numpy=b'Jawa barat'>, 'Nama_Gunung ': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Papandayan '>, 'Ketinggian ': <tf.Tensor: shape=(), dtype=string, numpy=b'2,666'>, 'Lokasi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Kab. Garut.'>, 'Trek': <tf.Tensor: shape=(), dtype=string, numpy=b'bebatuan '>, 'Jalur': <tf.Tensor: shape=(), dtype=string, numpy=b'-'>, 'Simaksi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Rp60.000'>, 'Level': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# {'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=104>, 'Daerah ': <tf.Tensor: shape=(), dtype=string, numpy=b'Jawa barat'>, 'Nama_Gunung ': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Gede Pangrango '>, 'Ketinggian ': <tf.Tensor: shape=(), dtype=string, numpy=b'2,958'>, 'Lokasi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Bogor'>, 'Trek': <tf.Tensor: shape=(), dtype=string, numpy=b'Tangga Buatan'>, 'Jalur': <tf.Tensor: shape=(), dtype=string, numpy=b'Jalur Cibodas dan Jalur Putri '>, 'Simaksi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Rp75.000'>, 'Level': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# {'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=105>, 'Daerah ': <tf.Tensor: shape=(), dtype=string, numpy=b'Jawa barat'>, 'Nama_Gunung ': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Pangrango'>, 'Ketinggian ': <tf.Tensor: shape=(), dtype=string, numpy=b'3,019'>, 'Lokasi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Cibodas'>, 'Trek': <tf.Tensor: shape=(), dtype=string, numpy=b'Akar Pohon  '>, 'Jalur': <tf.Tensor: shape=(), dtype=string, numpy=b'Jalur Cibodas'>, 'Simaksi ': <tf.Tensor: shape=(), dtype=string, numpy=b'Rp75.000'>, 'Level': <tf.Tensor: shape=(), dtype=int64, numpy=2>}

# %%
# get the first rows of the ratings dataset
for m in tf_rating.take(5):
  print(m)
# Out:
# {'user_id': <tf.Tensor: shape=(), dtype=int64, numpy=571>, 'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'mount_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai'>, 'rating': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'level': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'gender': <tf.Tensor: shape=(), dtype=string, numpy=b'Laki-laki'>, 'age': <tf.Tensor: shape=(), dtype=int64, numpy=61>}
# {'user_id': <tf.Tensor: shape=(), dtype=int64, numpy=463>, 'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'mount_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai'>, 'rating': <tf.Tensor: shape=(), dtype=int64, numpy=4>, 'level': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'gender': <tf.Tensor: shape=(), dtype=string, numpy=b'Perempuan'>, 'age': <tf.Tensor: shape=(), dtype=int64, numpy=21>}
# {'user_id': <tf.Tensor: shape=(), dtype=int64, numpy=972>, 'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'mount_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai'>, 'rating': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'level': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'gender': <tf.Tensor: shape=(), dtype=string, numpy=b'Laki-laki'>, 'age': <tf.Tensor: shape=(), dtype=int64, numpy=59>}
# {'user_id': <tf.Tensor: shape=(), dtype=int64, numpy=776>, 'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'mount_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai'>, 'rating': <tf.Tensor: shape=(), dtype=int64, numpy=5>, 'level': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'gender': <tf.Tensor: shape=(), dtype=string, numpy=b'Laki-laki'>, 'age': <tf.Tensor: shape=(), dtype=int64, numpy=51>}
# {'user_id': <tf.Tensor: shape=(), dtype=int64, numpy=863>, 'mountain_id': <tf.Tensor: shape=(), dtype=int64, numpy=101>, 'mount_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Gunung Cermai'>, 'rating': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'level': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'gender': <tf.Tensor: shape=(), dtype=string, numpy=b'Laki-laki'>, 'age': <tf.Tensor: shape=(), dtype=int64, numpy=49>}

# %% [markdown]
# # Data Preprocessing

# %%
## feature selection
# we use column user_id, mount_name, level, gender, and user_id from rating dataset
# from tf_mount dataset, we use mountain_id, mount_name and level column

ratings = tf_rating.map(lambda x: {
    "user_id": x["user_id"],
    "mount_name": x["mount_name"],
    "level": x["level"],
    "gender":x["gender"],
    "age": x["age"]

})
# gunung = tf_mount.map(lambda x: x["Nama_Gunung "])

mount =  tf_mount.map(lambda x: {
    "mountain_id": x["mountain_id"],
    "mount_name": x["Nama_Gunung "],
    "level": x["Level"]
})

# %%
# separate dataset to the training and testing


## Split dataset randomly (80% for train and 20% for test)
trainset_size = 0.8 * ratings.__len__().numpy()

# set the global seed to get same the same sequence of random numbers every time run the code:
tf.random.set_seed(42)

# Shuffle the elements of the dataset randomly.
ratings_dataset_shuffled = ratings.shuffle(
    # the new dataset will be sampled from a buffer window of first `buffer_size`
    # elements of the dataset
    buffer_size=100_000,
    # set the random seed that will be used to create the distribution.
    seed=42,
    # `list(dataset.as_numpy_iterator()` yields different result for each call
    # Because reshuffle_each_iteration defaults to True.
    reshuffle_each_iteration=False
)

ratings_trainset = ratings_dataset_shuffled.take(trainset_size)
ratings_testset = ratings_dataset_shuffled.skip(trainset_size)

# %%
# Check ratings_trainset dataset

from pprint import pprint

for rating in ratings_trainset.take(1).as_numpy_iterator():
  pprint(rating)
# Out:
# {'age': 50,
#  'gender': b'Perempuan',
#  'level': 2,
#  'mount_name': b'Gunung Papandayan',
#  'user_id': 524}

# %%
# Check ratings_testset dataset

from pprint import pprint

for rating in ratings_testset.take(1).as_numpy_iterator():
  pprint(rating)
# Out:
# {'age': 62,
#  'gender': b'Laki-laki',
#  'level': 3,
#  'mount_name': b'Gunung Lawu',
#  'user_id': 618}

# %%
# Make unique value for each column

unique_gender = np.unique(np.concatenate(list(ratings.map(lambda x: x["gender"]).batch(100))))
unique_level = np.unique(np.concatenate(list(ratings.map(lambda x: x["level"]).batch(100))))
unique_age = np.unique(np.concatenate(list(ratings.map(lambda x: x["age"]).batch(100))))


#unique_mount_names = np.unique(np.concatenate(list(mount.batch(1000))))
unique_mount_names = np.unique(np.concatenate(list(mount.map(lambda x: x["mount_name"]).batch(1000))))
unique_mount_lvl = np.unique(np.concatenate(list(mount.map(lambda x: x["level"]).batch(1000))))
unique_user_ids = np.unique(np.concatenate(list(ratings.batch(1000).map(
    lambda x: x["user_id"]))))

# %%
print(unique_mount_names)
# Out:
# [b'Gunung Argupuro' b'Gunung Arjuno' b'Gunung Cermai ' b'Gunung Cikuray '
#  b'Gunung Gede Pangrango ' b'Gunung Lawu' b'Gunung Merbabu'
#  b'Gunung Panderman' b'Gunung Pangrango' b'Gunung Papandayan '
#  b'Gunung Prau ' b'Gunung Puntang' b'Gunung Raung' b'Gunung Semeru'
#  b'Gunung Sindoro' b'Gunung Slamet' b'Gunung Sumbing']

# %%
print(len(unique_mount_names))
# Out:
# 17

# %%
# user_ids_vocabulary = tf.keras.layers.IntegerLookup(mask_token=None)
# user_ids_vocabulary.adapt(ratings_trainset.map(lambda x: x["user_id"]))


# gunung_name_vocabulary = tf.keras.layers.StringLookup(mask_token=None)
# gunung_name_vocabulary.adapt(gunung)

# %% [markdown]
# # Modelling

# %%
# !pip install -q tensorflow-recommenders
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 3.1 MB/s eta 0:00:00

# %%
import tensorflow_recommenders as tfrs

# %%
# Query Model


class UserModel(tf.keras.Model):

  def __init__(self, use_levels):
    super().__init__()

    self._use_levels = use_levels

    self.user_embedding = tf.keras.Sequential([
        tf.keras.layers.IntegerLookup(
            vocabulary=unique_user_ids, mask_token=None),
        tf.keras.layers.Embedding(len(unique_user_ids) + 1, 16),
    ])

    self.gender_embedding = tf.keras.Sequential([
          tf.keras.layers.StringLookup(
              vocabulary=unique_gender, mask_token=None),
          tf.keras.layers.Embedding(len(unique_gender) + 1, 16),
      ])

    self.age_embedding = tf.keras.Sequential([
          tf.keras.layers.IntegerLookup(
              vocabulary=unique_age, mask_token=None),
          tf.keras.layers.Embedding(len(unique_age) + 1, 16),
      ])


    if use_levels:
      self.level_embedding = tf.keras.Sequential([
          tf.keras.layers.IntegerLookup(
              vocabulary=unique_level, mask_token=None),
          tf.keras.layers.Embedding(len(unique_level) + 1, 16),
      ])

  def call(self, inputs):
    if not self._use_levels:
      return tf.concat([
        self.user_embedding(inputs["user_id"]),
        self.gender_embedding(inputs["gender"]),
        self.age_embedding(inputs["age"]),
    ], axis=1)

    return tf.concat([
        self.user_embedding(inputs["user_id"]),
        self.gender_embedding(inputs["gender"]),
        self.age_embedding(inputs["age"]),
        self.level_embedding(inputs["level"]),
    ], axis=1)

# %%
# Candidate Model

class MountModel(tf.keras.Model):

  def __init__(self):
    super().__init__()

    max_tokens = 10_000


    self.title_embedding = tf.keras.Sequential([
    tf.keras.layers.StringLookup(
          vocabulary=unique_mount_names, mask_token=None),
    tf.keras.layers.Embedding(len(unique_mount_names) + 1, 16)
])

    # apply tokenization (splitting into constituent words or word-pieces)
    self.title_vectorizer = tf.keras.layers.TextVectorization(
        max_tokens=max_tokens)

    self.title_text_embedding = tf.keras.Sequential([
      self.title_vectorizer,
      tf.keras.layers.Embedding(max_tokens, 16, mask_zero=True),
      tf.keras.layers.GlobalAveragePooling1D(),
    ])

    self.title_vectorizer.adapt(unique_mount_names)

    self.lvl_embedding = tf.keras.Sequential([
        tf.keras.layers.IntegerLookup(
            vocabulary=unique_mount_lvl, mask_token=None),
        tf.keras.layers.Embedding(len(unique_mount_lvl) + 1, 16),
    ])

  def call(self, inputs):
    return tf.concat([
        self.title_embedding(inputs['mount_name']),
        self.title_text_embedding(inputs['mount_name']),
        self.lvl_embedding(inputs['level'])
    ], axis=1)


      # def call(self, titles):
    #   len_titles = tf.shape(titles)[0]
    #   # return avg_layer(self.title_text_embedding(titles))
    #   return tf.concat([
    #       self.title_embedding(tf.reshape(titles,[len_titles,5,1])),
    #       self.title_text_embedding(tf.reshape(titles,[len_titles,5,1])),
    #   ], axis=1)

# %%
# Combined Model

class MountLensModel(tfrs.models.Model):

  def __init__(self, use_levels):
    super().__init__()
    self.query_model = tf.keras.Sequential([
      UserModel(use_levels),
      tf.keras.layers.Dense(16)
    ])
    self.candidate_model = tf.keras.Sequential([
      MountModel(),
      tf.keras.layers.Dense(16)
    ])
    self.task = tfrs.tasks.Retrieval(
        metrics=tfrs.metrics.FactorizedTopK(
            candidates=mount.batch(100).map(self.candidate_model),
        ),
    )
    self.dropout_layer = tf.keras.layers.Dropout(0.35)
    self.dense = tf.keras.layers.Dense(16, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00001))

  def compute_loss(self, features, training=False):
    # We only pass the user id and timestamp features into the query model. This
    # is to ensure that the training inputs would have the same keys as the
    # query inputs. Otherwise the discrepancy in input structure would cause an
    # error when loading the query model after saving it.
    query_embeddings = self.dropout_layer(self.query_model({
        "user_id": features["user_id"],
        "gender": features["gender"],
        "age": features["age"],
        "level": features["level"]
    }))
    query_embeddings = self.dense(query_embeddings)


   # mount_embeddings = self.dropout_layer(self.candidate_model(features["mount_name"]))
    mount_embeddings = self.dropout_layer(self.candidate_model({
        "mount_name": features["mount_name"],
        "level": features["level"],
        }))
    mount_embeddings = self.dense(mount_embeddings)

    return self.task(query_embeddings, mount_embeddings)

# %%
cached_train = ratings_trainset.shuffle(100_000).batch(156)
cached_test = ratings_testset.batch(80).cache()

# %%
model = MountLensModel(use_levels=True)
#model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))
model.compile(optimizer='adam')

history = model.fit(cached_train, validation_data=cached_test,
    validation_freq=1, epochs=5)

train_accuracy = model.evaluate(
    cached_train, return_dict=True)["factorized_top_k/top_5_categorical_accuracy"]
test_accuracy = model.evaluate(
    cached_test, return_dict=True)["factorized_top_k/top_5_categorical_accuracy"]

print(f"Top-5 accuracy (train): {train_accuracy:.2f}.")
print(f"Top-5 accuracy (test): {test_accuracy:.2f}.")
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'mountain_id': <tf.Tensor 'args_2:0' shape=(None,) dtype=int64>, 'mount_name': <tf.Tensor 'args_1:0' shape=(None,) dtype=string>, 'level': <tf.Tensor 'args_0:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# Epoch 1/5
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'mount_name': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'mount_name': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# 26/26 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.9068 - factorized_top_k/top_5_categorical_accuracy: 0.9872 - factorized_top_k/top_10_categorical_accuracy: 0.9992 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 774.4754 - regularization_loss: 5.5550e-04 - total_loss: 774.4759
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=string>, 'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'mount_name': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'level': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# 26/26 [==============================] - 10s 256ms/step - factorized_top_k/top_1_categorical_accuracy: 0.9068 - factorized_top_k/top_5_categorical_accuracy: 0.9872 - factorized_top_k/top_10_categorical_accuracy: 0.9992 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 762.7771 - regularization_loss: 5.5571e-04 - total_loss: 762.7777 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 146.8174 - val_regularization_loss: 5.6165e-04 - val_total_loss: 146.8180
# Epoch 2/5
# 26/26 [==============================] - 4s 154ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 747.7545 - regularization_loss: 5.7412e-04 - total_loss: 747.7551 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 137.9637 - val_regularization_loss: 5.8945e-04 - val_total_loss: 137.9642
# Epoch 3/5
# 26/26 [==============================] - 6s 211ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 689.0811 - regularization_loss: 6.0834e-04 - total_loss: 689.0817 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 120.8003 - val_regularization_loss: 6.2570e-04 - val_total_loss: 120.8009
# Epoch 4/5
# 26/26 [==============================] - 5s 207ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 656.7116 - regularization_loss: 6.3474e-04 - total_loss: 656.7123 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 115.8495 - val_regularization_loss: 6.4317e-04 - val_total_loss: 115.8501
# Epoch 5/5
# 26/26 [==============================] - 5s 177ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 634.7428 - regularization_loss: 6.5281e-04 - total_loss: 634.7435 - val_factorized_top_k/top_1_categorical_accuracy: 1.0000 - val_factorized_top_k/top_5_categorical_accuracy: 1.0000 - val_factorized_top_k/top_10_categorical_accuracy: 1.0000 - val_factorized_top_k/top_50_categorical_accuracy: 1.0000 - val_factorized_top_k/top_100_categorical_accuracy: 1.0000 - val_loss: 109.0714 - val_regularization_loss: 6.6331e-04 - val_total_loss: 109.0720
# 26/26 [==============================] - 3s 102ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 622.5219 - regularization_loss: 6.6331e-04 - total_loss: 622.5226
# 13/13 [==============================] - 1s 100ms/step - factorized_top_k/top_1_categorical_accuracy: 1.0000 - factorized_top_k/top_5_categorical_accuracy: 1.0000 - factorized_top_k/top_10_categorical_accuracy: 1.0000 - factorized_top_k/top_50_categorical_accuracy: 1.0000 - factorized_top_k/top_100_categorical_accuracy: 1.0000 - loss: 252.1133 - regularization_loss: 6.6331e-04 - total_loss: 252.1140
# Top-5 accuracy (train): 1.00.
# Top-5 accuracy (test): 1.00.

# %%
import matplotlib.pyplot as plt

# Plot changes in model loss during training
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model losses during training")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train", "test"], loc="upper right")
plt.show()

# %%
# Plot changes in model accuracy during training
plt.plot(history.history["factorized_top_k/top_5_categorical_accuracy"])
plt.plot(history.history["val_factorized_top_k/top_5_categorical_accuracy"])
plt.title("Model accuracies during training")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(["train", "test"], loc="upper right")
plt.show()

# %%
print(cached_test.take(1))
# Out:
# <_TakeDataset element_spec={'user_id': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'mount_name': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'level': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'gender': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'age': TensorSpec(shape=(None,), dtype=tf.int64, name=None)}>

# %% [markdown]
# # Give the recommend mounts

# %%
# Create a model that takes in raw query features, and
index = tfrs.layers.factorized_top_k.BruteForce(model.query_model)
# recommends movies out of the entire movies dataset.
tes = mount.batch(1)
# index.index_from_dataset(
#   tf.data.Dataset.zip((tes.map(lambda x: x["mount_name"]),tes.map(model.candidate_model)))
# )
index.index_from_dataset(
  tf.data.Dataset.zip((tes.map(lambda x: x["mount_name"]),tes.map(model.candidate_model)))
)
# index.index_from_dataset(
#     tes.map(lambda title: (title, model.candidate_model(title))))
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'mountain_id': <tf.Tensor 'args_2:0' shape=(None,) dtype=int64>, 'mount_name': <tf.Tensor 'args_1:0' shape=(None,) dtype=string>, 'level': <tf.Tensor 'args_0:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.

# %%
#Get recommendations.
query = {"user_id": np.array([100]),"gender": np.array(["Laki-laki"]),"age": np.array([90]),"level": np.array([2])}
_, titles = index(query)
print(f"Recommendations for user 100: {titles[0, :]}")
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([100])>, 'gender': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Laki-laki'], dtype=object)>, 'age': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([90])>, 'level': <tf.Tensor: shape=(1,), dtype=int64, numpy=array([2])>}. Consider rewriting this model with the Functional API.
# Recommendations for user 100: [b'Gunung Pangrango' b'Gunung Merbabu' b'Gunung Slamet' b'Gunung Sindoro'
#  b'Gunung Lawu' b'Gunung Panderman' b'Gunung Sumbing' b'Gunung Semeru'
#  b'Gunung Arjuno' b'Gunung Raung']

# %% [markdown]
# # Saving model

# %%
model_save_name = 'model'
path = F"/content/drive/My Drive/{model_save_name}"
tf.saved_model.save(index, path)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'inputs:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'inputs_1:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'inputs_2:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'inputs_3:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'inputs:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'inputs_1:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'inputs_2:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'inputs_3:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'queries_user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'queries_gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'queries_age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'queries_level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'queries_user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'queries_gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'queries_age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'queries_level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'inputs_user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'inputs_gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'inputs_age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'inputs_level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'user_id': <tf.Tensor 'inputs_user_id:0' shape=(None,) dtype=int64>, 'gender': <tf.Tensor 'inputs_gender:0' shape=(None,) dtype=string>, 'age': <tf.Tensor 'inputs_age:0' shape=(None,) dtype=int64>, 'level': <tf.Tensor 'inputs_level:0' shape=(None,) dtype=int64>}. Consider rewriting this model with the Functional API.
# WARNING:absl:Found untraced functions such as query_with_exclusions while saving (showing 1 of 1). These functions will not be directly callable after loading.

# %%
# Give recommendation from saved model

loaded = tf.saved_model.load("/content/drive/My Drive/model")

# Pass a user id in, get top predicted movie titles back.
query = {"user_id": np.array([100]),"gender": np.array(["Laki-laki"]),"age": np.array([90]),"level": np.array([3])}

scores, titles = loaded(query)

print(f"Recommendations: {titles[0][:3]}")
# Out:
# Recommendations: [b'Gunung Raung' b'Gunung Arjuno' b'Gunung Semeru']
